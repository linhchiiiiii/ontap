# %%
class SinhVien:
    def __init__(self, msv, hoTen, lop):
        self.msv = msv
        self.hoTen = hoTen
        self.lop = lop

    def infor(self):
        return f"{self.msv} {self.hoTen} {self.lop}"


def SVK18A3(SinhVien):
    def __init__(self, msv, hoTen, lop):
        super().__init__(msv, hoTen, lop)

    def infor(self):
        return f"{self.msv} {self.hoTen} {self.lop} K18A3"
